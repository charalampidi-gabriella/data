# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
data = pd.read_csv("Breast_cancer_data.csv")

# %%
data["diagnosis"].hist()
# Out:
# <Axes: >

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
# ignore correlated columns
data = data [["mean_radius","mean_texture", "mean_smoothness","diagnosis"]]
# Out:
#     mean_radius  mean_texture  mean_smoothness  diagnosis
# 0         17.99         10.38          0.11840          0
# 1         20.57         17.77          0.08474          0
# 2         19.69         21.25          0.10960          0
# 3         11.42         20.38          0.14250          0
# 4         20.29         14.34          0.10030          0
# 5         12.45         15.70          0.12780          0
# 6         18.25         19.98          0.09463          0
# 7         13.71         20.83          0.11890          0
# 8         13.00         21.82          0.12730          0
# 9         12.46         24.04          0.11860          0
# 10        16.02         23.24          0.08206          0
# 11        15.78         17.89          0.09710          0
# 12        19.17         24.80          0.09740          0
# 13        15.85         23.95          0.08401          0
# 14        13.73         22.61          0.11310          0
# ...

# %%
#identify distributions
sns.set_context("paper")
sns.displot(data = data, x = "mean_radius", kind = "hist", bins =50, height = 2,aspect = 1.5, color = 'r')
sns.displot(data = data, x = "mean_smoothness", kind = "hist", bins =50,height = 2, aspect = 1.5, color='y')
sns.displot(data = data, x = "mean_texture", kind = "hist", bins =50,height = 2, aspect = 1.5)
